# %%
import tensorflow as tf
import matplotlib.image as img
# %matplotlib inline
import numpy as np
from collections import defaultdict
import collections
from shutil import copy
from shutil import copytree, rmtree
import tensorflow.keras.backend as K
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt
import numpy as np
import os
import random
import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras import regularizers
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Convolution2D, MaxPooling2D, ZeroPadding2D, GlobalAveragePooling2D, AveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.regularizers import l2
from tensorflow import keras
from tensorflow.keras import models
import cv2

# %%
# Check if GPU is enabled
os.environ["CUDA_VISIBLE_DEVICES"]='0'
print(tf.__version__)
print(tf.test.gpu_device_name())
# Out:
# 2.2.0
# /device:GPU:0

# %%
tf.config.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:XLA_CPU:0', device_type='XLA_CPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'),
#  PhysicalDevice(name='/physical_device:XLA_GPU:0', device_type='XLA_GPU')]

# %% [markdown]
# Understanding dataset structure and files:
# The dataset being used is Food 101
#
# This dataset has 101000 images in total. It's a food dataset with 101 categories(multiclass)
# Each type of food has 750 training samples and 250 test samples

# %% [markdown]
# **images** folder contains 101 folders with 1000 images each
# Each folder contains images of a specific food class

# %%
os.listdir("C:/Users/sreem/food-101")
# Out:
# ['.ipynb_checkpoints', 'images', 'license_agreement.txt', 'meta', 'README.txt']

# %% [markdown]
# **meta** folder contains the text files - train.txt and test.txt
#
# **train.txt** contains the list of images that belong to training set
#
# **test.txt** contains the list of images that belong to test set
#
# **classes.txt** contains the list of all classes of food

# %%
os.listdir('C:/Users/sreem/food-101/meta')
# Out:
# ['classes.txt',
#  'labels.txt',
#  'test.json',
#  'test.txt',
#  'train.json',
#  'train.txt']

# %% [markdown]
# Visualize random image from each of the 101 classes

# %%
# Visualize the data, showing one image per class from 101 classes
rows = 17
cols = 6
fig, ax = plt.subplots(rows, cols, figsize=(25,25))
fig.suptitle("Showing one random image from each class", y=1.05, fontsize=24) # Adding  y=1.05, fontsize=24 helped me fix the suptitle overlapping with axes issue
data_dir = "C:/Users/sreem/food-101/images/"
foods_sorted = sorted(os.listdir(data_dir))
food_id = 0
for i in range(rows):
  for j in range(cols):
    try:
      food_selected = foods_sorted[food_id] 
      food_id += 1
    except:
      break
    if food_selected == '.DS_Store':
        continue
    food_selected_images = os.listdir(os.path.join(data_dir,food_selected)) # returns the list of all files present in each food category
    food_selected_random = np.random.choice(food_selected_images) # picks one food item from the list as choice, takes a list and returns one random item
    img = plt.imread(os.path.join(data_dir,food_selected, food_selected_random))
    ax[i][j].imshow(img)
    ax[i][j].set_title(food_selected, pad = 10)
    
plt.setp(ax, xticks=[],yticks=[])
plt.tight_layout()

# %% [markdown]
# Split the image data into train and test using train.txt and test.txt

# %%
# Helper method to split dataset into train and test folders
def prepare_data(filepath, src,dest):
  classes_images = defaultdict(list)
  with open(filepath, 'r') as txt:
      paths = [read.strip() for read in txt.readlines()]
      for p in paths:
        food = p.split('/')
        classes_images[food[0]].append(food[1] + '.jpg')

  for food in classes_images.keys():
    print("\nCopying images into ",food)
    if not os.path.exists(os.path.join(dest,food)):
      os.makedirs(os.path.join(dest,food))
    for i in classes_images[food]:
      copy(os.path.join(src,food,i), os.path.join(dest,food,i))
  print("Copying Done!")

# %%
# Prepare train dataset by copying images from food-101/images to food-101/train using the file train.txt
print("Creating train data...")
prepare_data('C:/Users/sreem/food-101/meta/train.txt', 'C:/Users/sreem/food-101/images/', 'train')
# Out:
# Creating train data...
#
# Copying images into  apple_pie
#
# Copying images into  baby_back_ribs
#
# Copying images into  baklava
#
# Copying images into  beef_carpaccio
#
# Copying images into  beef_tartare
#
# Copying images into  beet_salad
#
# Copying images into  beignets
#
# Copying images into  bibimbap
#
# Copying images into  bread_pudding
#
# Copying images into  breakfast_burrito
#
# Copying images into  bruschetta
#
# Copying images into  caesar_salad
#
# Copying images into  cannoli
#
# Copying images into  caprese_salad
#
# Copying images into  carrot_cake
#
# Copying images into  ceviche
#
# Copying images into  cheesecake
#
# Copying images into  cheese_plate
#
# Copying images into  chicken_curry
#
# Copying images into  chicken_quesadilla
#
# Copying images into  chicken_wings
#
# Copying images into  chocolate_cake
#
# Copying images into  chocolate_mousse
#
# Copying images into  churros
#
# Copying images into  clam_chowder
#
# Copying images into  club_sandwich
#
# Copying images into  crab_cakes
#
# Copying images into  creme_brulee
#
# Copying images into  croque_madame
#
# Copying images into  cup_cakes
#
# Copying images into  deviled_eggs
#
# Copying images into  donuts
#
# Copying images into  dumplings
#
# Copying images into  edamame
#
# Copying images into  eggs_benedict
#
# Copying images into  escargots
#
# Copying images into  falafel
#
# Copying images into  filet_mignon
#
# Copying images into  fish_and_chips
#
# Copying images into  foie_gras
#
# Copying images into  french_fries
#
# Copying images into  french_onion_soup
#
# Copying images into  french_toast
#
# Copying images into  fried_calamari
#
# Copying images into  fried_rice
#
# Copying images into  frozen_yogurt
#
# Copying images into  garlic_bread
#
# Copying images into  gnocchi
#
# Copying images into  greek_salad
#
# Copying images into  grilled_cheese_sandwich
#
# Copying images into  grilled_salmon
#
# Copying images into  guacamole
#
# Copying images into  gyoza
#
# Copying images into  hamburger
#
# Copying images into  hot_and_sour_soup
#
# Copying images into  hot_dog
#
# Copying images into  huevos_rancheros
#
# Copying images into  hummus
#
# Copying images into  ice_cream
#
# Copying images into  lasagna
#
# Copying images into  lobster_bisque
#
# Copying images into  lobster_roll_sandwich
#
# Copying images into  macaroni_and_cheese
#
# Copying images into  macarons
#
# Copying images into  miso_soup
#
# Copying images into  mussels
#
# Copying images into  nachos
#
# Copying images into  omelette
#
# Copying images into  onion_rings
#
# Copying images into  oysters
#
# Copying images into  pad_thai
#
# Copying images into  paella
#
# Copying images into  pancakes
#
# Copying images into  panna_cotta
#
# Copying images into  peking_duck
#
# Copying images into  pho
#
# Copying images into  pizza
#
# Copying images into  pork_chop
#
# Copying images into  poutine
#
# Copying images into  prime_rib
#
# Copying images into  pulled_pork_sandwich
#
# Copying images into  ramen
#
# Copying images into  ravioli
#
# Copying images into  red_velvet_cake
#
# Copying images into  risotto
#
# Copying images into  samosa
#
# Copying images into  sashimi
#
# Copying images into  scallops
#
# Copying images into  seaweed_salad
#
# Copying images into  shrimp_and_grits
#
# Copying images into  spaghetti_bolognese
#
# Copying images into  spaghetti_carbonara
#
# Copying images into  spring_rolls
#
# Copying images into  steak
#
# Copying images into  strawberry_shortcake
#
# Copying images into  sushi
#
# Copying images into  tacos
#
# Copying images into  takoyaki
#
# Copying images into  tiramisu
#
# Copying images into  tuna_tartare
#
# Copying images into  waffles
# Copying Done!

# %%
# Prepare test data by copying images from food-101/images to food-101/test using the file test.txt
print("Creating test data...")
prepare_data('C:/Users/sreem/food-101/meta/test.txt', 'C:/Users/sreem/food-101/images', 'test')
# Out:
# Creating test data...
#
# Copying images into  apple_pie
#
# Copying images into  baby_back_ribs
#
# Copying images into  baklava
#
# Copying images into  beef_carpaccio
#
# Copying images into  beef_tartare
#
# Copying images into  beet_salad
#
# Copying images into  beignets
#
# Copying images into  bibimbap
#
# Copying images into  bread_pudding
#
# Copying images into  breakfast_burrito
#
# Copying images into  bruschetta
#
# Copying images into  caesar_salad
#
# Copying images into  cannoli
#
# Copying images into  caprese_salad
#
# Copying images into  carrot_cake
#
# Copying images into  ceviche
#
# Copying images into  cheesecake
#
# Copying images into  cheese_plate
#
# Copying images into  chicken_curry
#
# Copying images into  chicken_quesadilla
#
# Copying images into  chicken_wings
#
# Copying images into  chocolate_cake
#
# Copying images into  chocolate_mousse
#
# Copying images into  churros
#
# Copying images into  clam_chowder
#
# Copying images into  club_sandwich
#
# Copying images into  crab_cakes
#
# Copying images into  creme_brulee
#
# Copying images into  croque_madame
#
# Copying images into  cup_cakes
#
# Copying images into  deviled_eggs
#
# Copying images into  donuts
#
# Copying images into  dumplings
#
# Copying images into  edamame
#
# Copying images into  eggs_benedict
#
# Copying images into  escargots
#
# Copying images into  falafel
#
# Copying images into  filet_mignon
#
# Copying images into  fish_and_chips
#
# Copying images into  foie_gras
#
# Copying images into  french_fries
#
# Copying images into  french_onion_soup
#
# Copying images into  french_toast
#
# Copying images into  fried_calamari
#
# Copying images into  fried_rice
#
# Copying images into  frozen_yogurt
#
# Copying images into  garlic_bread
#
# Copying images into  gnocchi
#
# Copying images into  greek_salad
#
# Copying images into  grilled_cheese_sandwich
#
# Copying images into  grilled_salmon
#
# Copying images into  guacamole
#
# Copying images into  gyoza
#
# Copying images into  hamburger
#
# Copying images into  hot_and_sour_soup
#
# Copying images into  hot_dog
#
# Copying images into  huevos_rancheros
#
# Copying images into  hummus
#
# Copying images into  ice_cream
#
# Copying images into  lasagna
#
# Copying images into  lobster_bisque
#
# Copying images into  lobster_roll_sandwich
#
# Copying images into  macaroni_and_cheese
#
# Copying images into  macarons
#
# Copying images into  miso_soup
#
# Copying images into  mussels
#
# Copying images into  nachos
#
# Copying images into  omelette
#
# Copying images into  onion_rings
#
# Copying images into  oysters
#
# Copying images into  pad_thai
#
# Copying images into  paella
#
# Copying images into  pancakes
#
# Copying images into  panna_cotta
#
# Copying images into  peking_duck
#
# Copying images into  pho
#
# Copying images into  pizza
#
# Copying images into  pork_chop
#
# Copying images into  poutine
#
# Copying images into  prime_rib
#
# Copying images into  pulled_pork_sandwich
#
# Copying images into  ramen
#
# Copying images into  ravioli
#
# Copying images into  red_velvet_cake
#
# Copying images into  risotto
#
# Copying images into  samosa
#
# Copying images into  sashimi
#
# Copying images into  scallops
#
# Copying images into  seaweed_salad
#
# Copying images into  shrimp_and_grits
#
# Copying images into  spaghetti_bolognese
#
# Copying images into  spaghetti_carbonara
#
# Copying images into  spring_rolls
#
# Copying images into  steak
#
# Copying images into  strawberry_shortcake
#
# Copying images into  sushi
#
# Copying images into  tacos
#
# Copying images into  takoyaki
#
# Copying images into  tiramisu
#
# Copying images into  tuna_tartare
#
# Copying images into  waffles
# Copying Done!

# %%
K.clear_session()
n_classes = 101
img_width, img_height = 299, 299
train_data_dir = 'train'
validation_data_dir = 'test'
nb_train_samples = 75750
nb_validation_samples = 25250
batch_size = 16

train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1. / 255)

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical')


resnet = ResNet50(weights='imagenet', include_top=False)
x = resnet.output
x = GlobalAveragePooling2D()(x)
x = Dense(128,activation='relu')(x)
x = Dropout(0.2)(x)

predictions = Dense(101,kernel_regularizer=regularizers.l2(0.005), activation='softmax')(x)

model = Model(inputs=resnet.input, outputs=predictions)
model.compile(optimizer=SGD(lr=0.0001, momentum=0.9), loss='categorical_crossentropy', metrics=['accuracy'])
checkpointer = ModelCheckpoint(filepath='model.hdf5', verbose=1, save_best_only=True)
csv_logger = CSVLogger('history.log')

history = model.fit_generator(train_generator,
                    steps_per_epoch = nb_train_samples // batch_size,
                    validation_data=validation_generator,
                    validation_steps=nb_validation_samples // batch_size,
                    epochs=30,
                    verbose=1,
                    callbacks=[csv_logger, checkpointer])

model.save('model_trained.hdf5')
# Out:
# Found 75750 images belonging to 101 classes.
# Found 25250 images belonging to 101 classes.
# WARNING:tensorflow:From <ipython-input-17-c5339b7476cb>:50: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/30
# 4734/4734 [==============================] - ETA: 0s - loss: 4.5934 - accuracy: 0.1209
# Epoch 00001: val_loss improved from inf to 3.39920, saving model to model.hdf5
# 4734/4734 [==============================] - 2258s 477ms/step - loss: 4.5934 - accuracy: 0.1209 - val_loss: 3.3992 - val_accuracy: 0.3607
# Epoch 2/30
# 4734/4734 [==============================] - ETA: 0s - loss: 3.2471 - accuracy: 0.3606
# Epoch 00002: val_loss improved from 3.39920 to 2.20373, saving model to model.hdf5
# 4734/4734 [==============================] - 2195s 464ms/step - loss: 3.2471 - accuracy: 0.3606 - val_loss: 2.2037 - val_accuracy: 0.5792
# Epoch 3/30
# 4734/4734 [==============================] - ETA: 0s - loss: 2.5717 - accuracy: 0.4912
# Epoch 00003: val_loss improved from 2.20373 to 1.83449, saving model to model.hdf5
# 4734/4734 [==============================] - 2165s 457ms/step - loss: 2.5717 - accuracy: 0.4912 - val_loss: 1.8345 - val_accuracy: 0.6477
# Epoch 4/30
# 4734/4734 [==============================] - ETA: 0s - loss: 2.2153 - accuracy: 0.5641
# Epoch 00004: val_loss improved from 1.83449 to 1.55985, saving model to model.hdf5
# 4734/4734 [==============================] - 2153s 455ms/step - loss: 2.2153 - accuracy: 0.5641 - val_loss: 1.5598 - val_accuracy: 0.7092
# Epoch 5/30
# 4734/4734 [==============================] - ETA: 0s - loss: 1.9834 - accuracy: 0.6083
# Epoch 00005: val_loss improved from 1.55985 to 1.46991, saving model to model.hdf5
# 4734/4734 [==============================] - 2156s 455ms/step - loss: 1.9834 - accuracy: 0.6083 - val_loss: 1.4699 - val_accuracy: 0.7227
# Epoch 6/30
# 4734/4734 [==============================] - ETA: 0s - loss: 1.8101 - accuracy: 0.6422
# Epoch 00006: val_loss improved from 1.46991 to 1.33324, saving model to model.hdf5
# 4734/4734 [==============================] - 2214s 468ms/step - loss: 1.8101 - accuracy: 0.6422 - val_loss: 1.3332 - val_accuracy: 0.7451
# Epoch 7/30
# 4734/4734 [==============================] - ETA: 0s - loss: 1.6739 - accuracy: 0.6703
# Epoch 00007: val_loss improved from 1.33324 to 1.26318, saving model to model.hdf5
# 4734/4734 [==============================] - 2171s 458ms/step - loss: 1.6739 - accuracy: 0.6703 - val_loss: 1.2632 - val_accuracy: 0.7577
# Epoch 8/30
# 4734/4734 [==============================] - ETA: 0s - loss: 1.5564 - accuracy: 0.6923
# Epoch 00008: val_loss did not improve from 1.26318
# 4734/4734 [==============================] - 2133s 451ms/step - loss: 1.5564 - accuracy: 0.6923 - val_loss: 1.3097 - val_accuracy: 0.7405
# Epoch 9/30
# 4734/4734 [==============================] - ETA: 0s - loss: 1.4556 - accuracy: 0.7108
# Epoch 00009: val_loss improved from 1.26318 to 1.12710, saving model to model.hdf5
# 4734/4734 [==============================] - 2210s 467ms/step - loss: 1.4556 - accuracy: 0.7108 - val_loss: 1.1271 - val_accuracy: 0.7814
# Epoch 10/30
# 4734/4734 [==============================] - ETA: 0s - loss: 1.3738 - accuracy: 0.7243
# Epoch 00010: val_loss improved from 1.12710 to 1.09642, saving model to model.hdf5
# 4734/4734 [==============================] - 2198s 464ms/step - loss: 1.3738 - accuracy: 0.7243 - val_loss: 1.0964 - val_accuracy: 0.7854
# Epoch 11/30
# 4734/4734 [==============================] - ETA: 0s - loss: 1.2915 - accuracy: 0.7422
# Epoch 00011: val_loss improved from 1.09642 to 1.07062, saving model to model.hdf5
# 4734/4734 [==============================] - 2234s 472ms/step - loss: 1.2915 - accuracy: 0.7422 - val_loss: 1.0706 - val_accuracy: 0.7889
# Epoch 12/30
# 4734/4734 [==============================] - ETA: 0s - loss: 1.2286 - accuracy: 0.7545
# Epoch 00012: val_loss did not improve from 1.07062
# 4734/4734 [==============================] - 2115s 447ms/step - loss: 1.2286 - accuracy: 0.7545 - val_loss: 1.0911 - val_accuracy: 0.7793
# Epoch 13/30
# 4734/4734 [==============================] - ETA: 0s - loss: 1.1631 - accuracy: 0.7656
# Epoch 00013: val_loss improved from 1.07062 to 1.00205, saving model to model.hdf5
# 4734/4734 [==============================] - 2115s 447ms/step - loss: 1.1631 - accuracy: 0.7656 - val_loss: 1.0021 - val_accuracy: 0.7976
# Epoch 14/30
# 4734/4734 [==============================] - ETA: 0s - loss: 1.1125 - accuracy: 0.7757
# Epoch 00014: val_loss did not improve from 1.00205
# 4734/4734 [==============================] - 2099s 443ms/step - loss: 1.1125 - accuracy: 0.7757 - val_loss: 1.0087 - val_accuracy: 0.7951
# Epoch 15/30
# 4734/4734 [==============================] - ETA: 0s - loss: 1.0584 - accuracy: 0.7875
# Epoch 00015: val_loss improved from 1.00205 to 0.96619, saving model to model.hdf5
# 4734/4734 [==============================] - 2099s 443ms/step - loss: 1.0584 - accuracy: 0.7875 - val_loss: 0.9662 - val_accuracy: 0.8038
# Epoch 16/30
# 4734/4734 [==============================] - ETA: 0s - loss: 1.0083 - accuracy: 0.7971
# Epoch 00016: val_loss improved from 0.96619 to 0.94622, saving model to model.hdf5
# 4734/4734 [==============================] - 2094s 442ms/step - loss: 1.0083 - accuracy: 0.7971 - val_loss: 0.9462 - val_accuracy: 0.8074
# Epoch 17/30
# 4734/4734 [==============================] - ETA: 0s - loss: 0.9601 - accuracy: 0.8051
# Epoch 00017: val_loss improved from 0.94622 to 0.92100, saving model to model.hdf5
# 4734/4734 [==============================] - 2094s 442ms/step - loss: 0.9601 - accuracy: 0.8051 - val_loss: 0.9210 - val_accuracy: 0.8108
# Epoch 18/30
# 4734/4734 [==============================] - ETA: 0s - loss: 0.9157 - accuracy: 0.8154
# Epoch 00018: val_loss did not improve from 0.92100
# 4734/4734 [==============================] - 2095s 442ms/step - loss: 0.9157 - accuracy: 0.8154 - val_loss: 0.9366 - val_accuracy: 0.8055
# Epoch 19/30
# 4734/4734 [==============================] - ETA: 0s - loss: 0.8803 - accuracy: 0.8214
# Epoch 00019: val_loss did not improve from 0.92100
# 4734/4734 [==============================] - 2095s 443ms/step - loss: 0.8803 - accuracy: 0.8214 - val_loss: 0.9479 - val_accuracy: 0.7994
# Epoch 20/30
# 4734/4734 [==============================] - ETA: 0s - loss: 0.8382 - accuracy: 0.8324
# Epoch 00020: val_loss improved from 0.92100 to 0.89946, saving model to model.hdf5
# 4734/4734 [==============================] - 2097s 443ms/step - loss: 0.8382 - accuracy: 0.8324 - val_loss: 0.8995 - val_accuracy: 0.8122
# Epoch 21/30
# 4734/4734 [==============================] - ETA: 0s - loss: 0.8023 - accuracy: 0.8392
# Epoch 00021: val_loss improved from 0.89946 to 0.89566, saving model to model.hdf5
# 4734/4734 [==============================] - 2097s 443ms/step - loss: 0.8023 - accuracy: 0.8392 - val_loss: 0.8957 - val_accuracy: 0.8127
# Epoch 22/30
# 4734/4734 [==============================] - ETA: 0s - loss: 0.7675 - accuracy: 0.8465
# Epoch 00022: val_loss improved from 0.89566 to 0.86650, saving model to model.hdf5
# 4734/4734 [==============================] - 2096s 443ms/step - loss: 0.7675 - accuracy: 0.8465 - val_loss: 0.8665 - val_accuracy: 0.8175
# Epoch 23/30
# 4734/4734 [==============================] - ETA: 0s - loss: 0.7380 - accuracy: 0.8512
# Epoch 00023: val_loss did not improve from 0.86650
# 4734/4734 [==============================] - 2095s 443ms/step - loss: 0.7380 - accuracy: 0.8512 - val_loss: 0.8729 - val_accuracy: 0.8178
# Epoch 24/30
# 4734/4734 [==============================] - ETA: 0s - loss: 0.7023 - accuracy: 0.8605
# Epoch 00024: val_loss did not improve from 0.86650
# 4734/4734 [==============================] - 2095s 443ms/step - loss: 0.7023 - accuracy: 0.8605 - val_loss: 0.8766 - val_accuracy: 0.8174
# Epoch 25/30
# 4734/4734 [==============================] - ETA: 0s - loss: 0.6791 - accuracy: 0.8650
# Epoch 00025: val_loss improved from 0.86650 to 0.85686, saving model to model.hdf5
# 4734/4734 [==============================] - 2096s 443ms/step - loss: 0.6791 - accuracy: 0.8650 - val_loss: 0.8569 - val_accuracy: 0.8190
# Epoch 26/30
# 4734/4734 [==============================] - ETA: 0s - loss: 0.6504 - accuracy: 0.8718
# Epoch 00026: val_loss did not improve from 0.85686
# 4734/4734 [==============================] - 2095s 443ms/step - loss: 0.6504 - accuracy: 0.8718 - val_loss: 0.8597 - val_accuracy: 0.8194
# Epoch 27/30
# 4734/4734 [==============================] - ETA: 0s - loss: 0.6262 - accuracy: 0.8768
# Epoch 00027: val_loss did not improve from 0.85686
# 4734/4734 [==============================] - 2096s 443ms/step - loss: 0.6262 - accuracy: 0.8768 - val_loss: 0.8694 - val_accuracy: 0.8178
# Epoch 28/30
# 4734/4734 [==============================] - ETA: 0s - loss: 0.6031 - accuracy: 0.8838
# Epoch 00028: val_loss did not improve from 0.85686
# 4734/4734 [==============================] - 2099s 443ms/step - loss: 0.6031 - accuracy: 0.8838 - val_loss: 0.8773 - val_accuracy: 0.8147
# Epoch 29/30
# 4734/4734 [==============================] - ETA: 0s - loss: 0.5784 - accuracy: 0.8871
# Epoch 00029: val_loss did not improve from 0.85686
# 4734/4734 [==============================] - 2098s 443ms/step - loss: 0.5784 - accuracy: 0.8871 - val_loss: 0.8778 - val_accuracy: 0.8132
# Epoch 30/30
# 4734/4734 [==============================] - ETA: 0s - loss: 0.5538 - accuracy: 0.8942
# Epoch 00030: val_loss improved from 0.85686 to 0.85115, saving model to model.hdf5
# 4734/4734 [==============================] - 2101s 444ms/step - loss: 0.5538 - accuracy: 0.8942 - val_loss: 0.8512 - val_accuracy: 0.8208

# %% [markdown]
# ### The accuray on the test set is 82%

# %%
def plot_accuracy(history,title):
    plt.title(title)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train_accuracy', 'validation_accuracy'], loc='best')
    plt.show()
def plot_loss(history,title):
    plt.title(title)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train_loss', 'validation_loss'], loc='best')
    plt.show()

# %%
# Visualize the training process
plot_accuracy(history,'FOOD101_resnet50')
plot_loss(history,'FOOD101_resnet50')
